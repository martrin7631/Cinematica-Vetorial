# %%
# Centro Universitário FEI

# Criado por Marcelo Santos Trindade em 24/04/2023

# "Elaboração de programas em Python como apoio didático na disciplina de Física I para estudantes ingressantes".

# Programa desenvolvido como parte de um projeto de Iniciação Didática com objetivo de estudar Python como ferramenta auxiliar para o ensino de Física I no Centro Universitário FEI.

import matplotlib.pyplot as plt
import numpy as np


# Função para imprimir o texto em verde ou vermelho
def print_verde(texto):
    print('\033[32m{}\033[0m'.format(texto))


def print_vermelho(texto):
    print('\033[31m{}\033[0m'.format(texto))


# Define os vetores como arrays numpy
v1 = np.array([15*np.cos(np.radians(60)), 15*np.sin(np.radians(60))])
v2 = np.array([10*np.cos(np.radians(135)), 10*np.sin(np.radians(135))])
v3 = np.array([12*np.cos(np.radians(180)), 12*np.sin(np.radians(180))])
v4 = np.array([12*np.cos(np.radians(270)), 12*np.sin(np.radians(270))])
v5 = np.array([10, 0])

# Cria a figura e o eixo
fig, ax = plt.subplots()
ax.set_aspect('equal')

# Define o tamanho do eixo e adiciona as setas e textos dos vetores
ax.set_xlim([-20, 20])
ax.set_ylim([-20, 20])
ax.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color='r')
ax.text(v1[0], v1[1], f"Vetor 1\n {np.linalg.norm(v1):.2f} \n 60°", ha='right', va='bottom', color='r')
ax.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='g')
ax.text(v2[0], v2[1], f"Vetor 2\n {np.linalg.norm(v2):.2f} \n 135°", ha='right', va='bottom', color='g')
ax.quiver(0, 0, v3[0], v3[1], angles='xy', scale_units='xy', scale=1, color='b')
ax.text(v3[0], v3[1], f"Vetor 3\n {np.linalg.norm(v3):.2f} \n 180°", ha='right', va='bottom', color='b')
ax.quiver(0, 0, v4[0], v4[1], angles='xy', scale_units='xy', scale=1, color='black')
ax.text(v4[0], v4[1], f"Vetor 4\n {np.linalg.norm(v4):.2f} \n 270°", ha='right', va='bottom', color='black')
ax.quiver(0, 0, v5[0], v5[1], angles='xy', scale_units='xy', scale=1, color='purple')
ax.text(v5[0], v5[1], f"Vetor 5\n {np.linalg.norm(v5):.2f} \n 0° ou 360°", ha='right', va='bottom', color='purple')

# Desenha os eixos x e y
ax.axhline(0, color='k', lw=1)
ax.axvline(0, color='k', lw=1)

# Adiciona a grade
ax.grid(True, which='both', linestyle=':', color='gray')

# Altera a cor do texto da legenda para preto
for text in ax.texts:
    text.set_color('k')

print('                               VETORES                               ')
print('---------------------------------------------------------------------')
print('Em física, um vetor é uma entidade matemática que possui módulo, direção e sentido. Ele é usado\n'
      'para representar grandezas físicas que têm essas três características, como a velocidade, a força\n'
      'e o deslocamento.\n'
      'Os vetores são geralmente representados graficamente como setas em um plano cartesiano, onde a direção\n'
      'é o ângulo que ele forma com o eixo x positivo, contado do sentido anti-horário, a seta indica o sentido\n'
      'e o comprimento da seta representa o módulo. Além disso, os vetores podem ser adicionados e subtraídos\n'
      'entre si, obedecendo as leis da geometria vetorial.\n'
      'Uma outra forma de representar um vetor é por meio das suas componentes x e y.\n'
      'O objetivo dessa atividade é trabalharmos com os vetores representados na figura abaixo, determinando\n'
      'suas componentes e operações vetoriais entre eles.')

# Mostra o gráfico
plt.show()

print('Na figura, podemos ver alguns vetores. Os tamanhos (módulos) estão indicados, e logo abaixo deles \n'
      'estão os ângulos que eles formam com o eixo x (sentido anti-horário).\n'
      'Como os valores não estão acompanhados\n'
      'de suas respectivas unidades, eles podem representar qualquer grandeza física vetorial.\n\n')
print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 1                                             ')
print('---------------------------------------------------------------------------------------------')
print('Para o vetor 1 (vermelho), determine a componente î (eixo x). O valor é aproximadamente:\n'
      '1) 7.5î\n'
      '2) 13î\n'
      '3) 15î\n')
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2 ou 3): '))
        if q1 in [1, 2, 3]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 3.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 1:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 2:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Lembre-se: COS = comp. horizontal e SEN = comp. vertical. Tente novamente: '))
        elif q1 == 3:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Lembre-se que para calcular a componente horizontal \n'
                           'multiplicamos o valor de vetor pelo cosseno do ângulo formado. Tente novamente: '))
        elif q1 == 1:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Por favor, digite um número entre 1 e 3: '))

print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 2                                             ')
print('---------------------------------------------------------------------------------------------')
print('Ainda para o vetor 1 (vermelho), determine a componente j (eixo y). O valor é aproximadamente:\n'
      '1) 7.5j\n'
      '2) 60j\n'
      '3) 13j\n'
      '4) -13j\n')
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Esta seria a componente i (eixo x). Tente novamente: '))
        elif q1 == 2:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Para calcular a componente y devemos multiplicar o módulo do vetor '
                           'pelo seno do ângulo formado. Tente novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Na figura podemos ver que o vetor está no primeiro quadrante, '
                           'indicando valor positivo para a componente y. Tente novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))

print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 3                                             ')
print('---------------------------------------------------------------------------------------------')
print("Escrevendo o vetor 2 (verde) em termos de 'i' e 'j' obtemos: \n"
      "1) 7,07i + 7,07j\n"
      "2) -7,07i + 7,07j\n"
      "3) -7,07i - 7,07j\n"
      "4) NDA\n")
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 2:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta')
            q1 = int(input('No segundo quadrante, "x" é negativo e "y" é positivo. Tente '
                           'novamente: '))
        elif q1 == 3:
            print_vermelho('Resposta incorreta')
            q1 = int(input('No segundo quadrante, "x" é negativo e "y" é positivo. Tente '
                           'novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Tente novamente: '))
        elif q1 == 2:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))


print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 4                                             ')
print('---------------------------------------------------------------------------------------------')
print('Ao somar o vetor 5 (roxo) com o vetor 3 (azul), qual alternativa representa o vetor resultante?\n'
      '1) 22i\n'
      '2) 2i\n'
      '3) -2i\n'
      '4) NDA\n')
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Atente-se: os vetores têm sentidos opostos. Tente '
                           'novamente: '))
        elif q1 == 2:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('O vetor resultante aponta contra o eixo x. Tente '
                           'novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Tente novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))

print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 5                                             ')
print('---------------------------------------------------------------------------------------------')
print('Para calcular o módulo da soma do vetor 4 (preto) com o vetor 3 (azul), devemos:\n'
      '1) Somar os módulos diretamente.\n'
      '2) Utilizar a regra do paralelogramo e então a Lei dos Cossenos.\n'
      '3) Utilizar a regra do paralelogramo e então o Teorema de Pitágoras.\n')
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2 ou 3): '))
        if q1 in [1, 2, 3]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 3.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 2:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('A Lei dos Cossenos é desnecessária pois os vetores '
                           'formam 90° entre si. Tente novamente: '))
        elif q1 == 1:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Isso só pode ser feito quando os vetores têm a '
                           'mesma direção. Tente novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta. A regra do paralelogramo consiste em desenhar vetores paralelos aos que se '
                        'quer somar, formando um paralelogramo, e então traçar a diagonal e calcular seu valor.')
            break
        else:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Por favor, digite um número entre 1 e 3: '))

print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 6                                             ')
print('---------------------------------------------------------------------------------------------')
print('O vetor resultante da soma do vetor 4 (preto) com o vetor 3 (azul) tem módulo de, aproximadamente:\n'
      '1) 12\n'
      '2) 13.5\n'
      '3) 17\n'
      '4) NDA')
while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 2:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))

print('---------------------------------------------------------------------------------------------')
print('                                       QUESTÃO 7                                             ')
print('---------------------------------------------------------------------------------------------')
print('a) Ao realizar a operação de subtração "Vetor4(preto) - Vetor5(roxo)", qual é o módulo do vetor resultante?:\n'
      '1) 17\n'
      '2) 11\n'
      '3) 15,6\n'
      '4) NDA')

while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 2:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Lembre-se: regra do paralelogramo e pitágoras. Tente '
                           'novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))

print('b) Ao realizar essa operação, obtemos um vetor resultante contido no terceiro quadrante. Dito isso,\n'
      'suas componentes "i" e "j" são, respectivamente:\n'
      '1) positivo e positivo\n'
      '2) positivo e negativo\n'
      '3) negativo e negativo\n'
      '4) positivo e negativo')

while True:
    try:
        q1 = int(input('Digite o número da alternativa correta (1, 2, 3 ou 4): '))
        if q1 in [1, 2, 3, 4]:
            break
        else:
            print_vermelho('Por favor, digite um número entre 1 e 4.')
    except ValueError:
        print_vermelho('Por favor, digite um número inteiro válido.')

if q1 == 3:
    print_verde('Parabéns! Resposta correta.')
else:
    while True:
        if q1 == 1:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Esse caso ocorre no primeiro quadrante. Tente novamente: '))
        elif q1 == 2:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Esse caso ocorre no segundo quadrante. Tente novamente: '))
        elif q1 == 4:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Esse caso ocorre no quarto quadrante: Tente novamente: '))
        elif q1 == 3:
            print_verde('Resposta correta.')
            break
        else:
            print_vermelho('Resposta incorreta.')
            q1 = int(input('Por favor, digite um número entre 1 e 4: '))
print_verde('\n\n\n Parabéns! Você concluiu todos os exercícios.')
# Out:
#                                VETORES
# ---------------------------------------------------------------------
# Em física, um vetor é uma entidade matemática que possui módulo, direção e sentido. Ele é usado
# para representar grandezas físicas que têm essas três características, como a velocidade, a força
# e o deslocamento.
# Os vetores são geralmente representados graficamente como setas em um plano cartesiano, onde a direção
# é o ângulo que ele forma com o eixo x positivo, contado do sentido anti-horário, a seta indica o sentido
# e o comprimento da seta representa o módulo. Além disso, os vetores podem ser adicionados e subtraídos
# entre si, obedecendo as leis da geometria vetorial.
# Uma outra forma de representar um vetor é por meio das suas componentes x e y.
# O objetivo dessa atividade é trabalharmos com os vetores representados na figura abaixo, determinando
# suas componentes e operações vetoriais entre eles.
# ...
